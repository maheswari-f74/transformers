# %% [markdown]
# <a href="https://colab.research.google.com/github/maheswari-f74/transformers/blob/main/transformers1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers

# %%
from transformers import pipeline

# %%
translator = pipeline('translation_en_to_de')
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
text = input('Enter some text: ')
# Out:
# Enter some text: i love india

# %%
result = translator(text)

# %%
result
# Out:
# [{'translation_text': 'i love india'}]

# %%
f_n = pipeline('fill-mask')
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# ...

# %%
text = input('Enter sentence <mask> ')
# Out:
# Enter sentence <mask> i love <mask> mangoes

# %%
result = f_n(text)

# %%
result
# Out:
# [{'score': 0.0698600709438324,
#   'token': 32184,
#   'token_str': ' mango',
#   'sequence': 'i love mango mangoes'},
#  {'score': 0.04518642649054527,
#   'token': 33336,
#   'token_str': ' pineapple',
#   'sequence': 'i love pineapple mangoes'},
#  {'score': 0.04058218002319336,
#   'token': 24042,
#   'token_str': ' spicy',
#   'sequence': 'i love spicy mangoes'},
#  {'score': 0.02611202374100685,
#   'token': 23611,
#   'token_str': ' banana',
#   'sequence': 'i love banana mangoes'},
#  {'score': 0.023913774639368057,
#   'token': 32042,
#   'token_str': ' crispy',
#   'sequence': 'i love crispy mangoes'}]

# %%
#VISUAL Q_A
vqa_pipeline = pipeline('visual-question-answering')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# ...

# %%
image=r'/content/peacock.jfif'

# %%
question=input('enter a question to ask about image:')
result=vqa_pipeline(image,question)
print (result)
# Out:
# enter a question to ask about image:which bird was there in image?
# [{'score': 0.8620125651359558, 'answer': 'peacock'}, {'score': 0.06378892064094543, 'answer': 'parrot'}, {'score': 0.04637093096971512, 'answer': 'blue'}, {'score': 0.03271355479955673, 'answer': 'both'}, {'score': 0.025878962129354477, 'answer': 'blue jay'}]
